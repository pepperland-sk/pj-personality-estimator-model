# %% [markdown]
# # PersonalityEstimatorModel

# %% [markdown]
# ## Import Packages

# %%
from math import floor, ceil
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
import gensim
import os
import collections
import pickle
import smart_open
import random
import re

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv("../input/mbti_1.csv")
df.head()
# Out:
#    type                                              posts
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  ENTP  'I'm finding the lack of me in these posts ver...
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4  ENTJ  'You're fired.|||That's another silly misconce...

# %%
# confirm data types
df.groupby("type").count()
# Out:
#       posts
# type
# ENFJ    190
# ENFP    675
# ENTJ    231
# ENTP    685
# ESFJ     42
# ESFP     48
# ESTJ     39
# ESTP     89
# INFJ   1470
# INFP   1832
# INTJ   1091
# INTP   1304
# ISFJ    166
# ISFP    271
# ISTJ    205
# ISTP    337

# %%
# visualize records per types
f, ax = plt.subplots(figsize = (20, 8))
ax = sns.countplot(df["type"])
plt.title("records per types")
plt.savefig("../output/records per types.png")

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Change line unit from users to posts

# %%
def extract(posts, new_posts):
    for post in posts[1].split("|||"):
        new_posts.append((posts[0], post))

posts = []
df.apply(lambda x: extract(x, posts), axis=1)
df = pd.DataFrame(posts, columns=["type", "posts"])

# %%
df
# Out:
#         type                                              posts
# 0       INFJ        'http://www.youtube.com/watch?v=qsXHcwe3krw
# 1       INFJ  http://41.media.tumblr.com/tumblr_lfouy03PMA1q...
# 2       INFJ  enfp and intj moments  https://www.youtube.com...
# 3       INFJ  What has been the most life-changing experienc...
# 4       INFJ  http://www.youtube.com/watch?v=vXZeYwwRDw8   h...
# ...      ...                                                ...
# 422840  INFP  I was going to close my facebook a few months ...
# 422841  INFP  30 Seconds to Mars - All of my collections. It...
# 422842  INFP  I have seen it, and i agree. I did actually th...
# 422843  INFP  Ok so i have just watched Underworld 4 (Awaken...
# 422844  INFP  I would never want to turn off my emotions. so...
#
# [422845 rows x 2 columns]

# %% [markdown]
# ### Preprocess and subsampling using gensim

# %%
def preprocess_text(df, remove_special=True):

    #Remove links 
    df["posts"] = df["posts"].apply(lambda x: re.sub(r'https?:\/\/.*?[\s+]', '', x.replace("|"," ") + " "))
    
    #Strip Punctation
    df["posts"] = df["posts"].apply(lambda x: re.sub(r'[^\w\s]','',x))

    #Remove Non-words
    df["posts"] = df["posts"].apply(lambda x: re.sub(r'[^a-zA-Z\s]','',x))

    #Remove multiple letter repating words
    df["posts"] = df["posts"].apply(lambda x: re.sub(r'([a-z])\1{2,}[\s|\w]*','',x)) 

    #Remove Personality Types Words
    if remove_special:
        pers_types = ['INFP' ,'INFJ', 'INTP', 'INTJ', 'ENTP', 'ENFP', 'ISTP' ,'ISFP' ,'ENTJ', 'ISTJ','ENFJ', 'ISFJ' ,'ESTP', 'ESFP' ,'ESFJ' ,'ESTJ']
        pers_types = [p.lower() for p in pers_types]
        p = re.compile("(" + "|".join(pers_types) + ")")

    df["posts"] = df["posts"].apply(lambda x: p.sub(' TokenType ',x))
    return df

def subsample(df):
    groups = df.groupby("type").count()
    groups.sort_values("posts", ascending=False, inplace=True)
    
    min_num = groups["posts"][-1]
    min_ind = groups.index[-1]
    ndf = df[df["type"] == min_ind]

    for pt in groups.index[:-1]:
        print(min_num,pt)
        tdf = df[df["type"] == pt].sample(min_num)
        ndf = pd.concat([ndf, tdf])
    return ndf

def read_corpus(df):
    # preprocess
#     df = subsample(preprocess_text(df))
    df = preprocess_text(df)
    
    for index, row in df.iterrows():
        yield gensim.models.doc2vec.TaggedDocument(words=gensim.utils.simple_preprocess(row['posts']), tags=row['type'])

df = list(read_corpus(df))
with open("../output/all_data.pickle", "wb") as f:
    pickle.dump(df, f)

# %%
df
# Out:
# [TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['tokentype', 'and', 'tokentype', 'moments', 'sportscenter', 'not', 'top', 'ten', 'plays', 'pranks'], tags='INFJ'),
#  TaggedDocument(words=['what', 'has', 'been', 'the', 'most', 'lifechanging', 'experience', 'in', 'your', 'life'], tags='INFJ'),
#  TaggedDocument(words=['on', 'repeat', 'for', 'most', 'of', 'today'], tags='INFJ'),
#  TaggedDocument(words=['may', 'the', 'perc', 'experience', 'immerse', 'you'], tags='INFJ'),
#  TaggedDocument(words=['the', 'last', 'thing', 'my', 'infj', 'friend', 'posted', 'on', 'his', 'facebook', 'before', 'committing', 'suicide', 'the', 'next', 'day', 'rest', 'in', 'peace'], tags='INFJ'),
#  TaggedDocument(words=['hello', 'enfj', 'sorry', 'to', 'hear', 'of', 'your', 'distress', 'its', 'only', 'natural', 'for', 'relationship', 'to', 'not', 'be', 'perfection', 'all', 'the', 'time', 'in', 'every', 'moment', 'of', 'existence', 'try', 'to', 'figure', 'the', 'hard', 'times', 'as', 'times', 'of', 'growth', 'as'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['welcome', 'and', 'stuff'], tags='INFJ'),
#  TaggedDocument(words=['game', 'set', 'match'], tags='INFJ'),
#  TaggedDocument(words=['prozac', 'wellbrutin', 'at', 'least', 'thirty', 'minutes', 'of', 'moving', 'your', 'legs', 'and', 'dont', 'mean', 'moving', 'them', 'while', 'sitting', 'in', 'your', 'same', 'desk', 'chair', 'weed', 'in', 'moderation', 'maybe', 'try', 'edibles', 'as', 'healthier', 'alternative'], tags='INFJ'),
#  TaggedDocument(words=['basically', 'come', 'up', 'with', 'three', 'items', 'youve', 'determined', 'that', 'each', 'type', 'or', 'whichever', 'types', 'you', 'want', 'to', 'do', 'would', 'more', 'than', 'likely', 'use', 'given', 'each', 'types', 'cognitive', 'functions', 'and', 'whatnot', 'when', 'left', 'by'], tags='INFJ'),
#  TaggedDocument(words=['all', 'things', 'in', 'moderation', 'sims', 'is', 'indeed', 'video', 'game', 'and', 'good', 'one', 'at', 'that', 'note', 'good', 'one', 'at', 'that', 'is', 'somewhat', 'subjective', 'in', 'that', 'am', 'not', 'completely', 'promoting', 'the', 'death', 'of', 'any', 'given', 'sim'], tags='INFJ'),
#  TaggedDocument(words=['dear', 'enfp', 'what', 'were', 'your', 'favorite', 'video', 'games', 'growing', 'up', 'and', 'what', 'are', 'your', 'now', 'current', 'favorite', 'video', 'games', 'cool'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['it', 'appears', 'to', 'be', 'too', 'late', 'sad'], tags='INFJ'),
#  TaggedDocument(words=['theres', 'someone', 'out', 'there', 'for', 'everyone'], tags='INFJ'),
#  TaggedDocument(words=['wait', 'thought', 'confidence', 'was', 'good', 'thing'], tags='INFJ'),
#  TaggedDocument(words=['just', 'cherish', 'the', 'time', 'of', 'solitude', 'bc', 'revel', 'within', 'my', 'inner', 'world', 'more', 'whereas', 'most', 'other', 'time', 'id', 'be', 'workin', 'just', 'enjoy', 'the', 'me', 'time', 'while', 'you', 'can', 'dont', 'worry', 'people', 'will', 'always', 'be', 'around', 'to'], tags='INFJ'),
#  TaggedDocument(words=['yo', 'tokentype', 'ladies', 'if', 'youre', 'into', 'complimentary', 'personalitywell', 'hey'], tags='INFJ'),
#  TaggedDocument(words=['when', 'your', 'main', 'social', 'outlet', 'is', 'xbox', 'live', 'conversations', 'and', 'even', 'then', 'you', 'verbally', 'fatigue', 'quickly'], tags='INFJ'),
#  TaggedDocument(words=['really', 'dig', 'the', 'part', 'from', 'to'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['banned', 'because', 'this', 'thread', 'requires', 'it', 'of', 'me'], tags='INFJ'),
#  TaggedDocument(words=['get', 'high', 'in', 'backyard', 'roast', 'and', 'eat', 'marshmellows', 'in', 'backyard', 'while', 'conversing', 'over', 'something', 'intellectual', 'followed', 'by', 'massages', 'and', 'kisses'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['banned', 'for', 'too', 'many', 'bs', 'in', 'that', 'sentence', 'how', 'could', 'you', 'think', 'of', 'the'], tags='INFJ'),
#  TaggedDocument(words=['banned', 'for', 'watching', 'movies', 'in', 'the', 'corner', 'with', 'the', 'dunces'], tags='INFJ'),
#  TaggedDocument(words=['banned', 'because', 'health', 'class', 'clearly', 'taught', 'you', 'nothing', 'about', 'peer', 'pressure'], tags='INFJ'),
#  TaggedDocument(words=['banned', 'for', 'whole', 'host', 'of', 'reasons'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['two', 'baby', 'deer', 'on', 'left', 'and', 'right', 'munching', 'on', 'beetle', 'in', 'the', 'middle', 'using', 'their', 'own', 'blood', 'two', 'cavemen', 'diary', 'todays', 'latest', 'happenings', 'on', 'their', 'designated', 'cave', 'diary', 'wall', 'see', 'it', 'as'], tags='INFJ'),
#  TaggedDocument(words=['pokemon', 'world', 'an', 'tokentype', 'society', 'everyone', 'becomes', 'an', 'optimist'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['not', 'all', 'artists', 'are', 'artists', 'because', 'they', 'draw', 'its', 'the', 'idea', 'that', 'counts', 'in', 'forming', 'something', 'of', 'your', 'own', 'like', 'signature'], tags='INFJ'),
#  TaggedDocument(words=['welcome', 'to', 'the', 'robot', 'ranks', 'person', 'who', 'downed', 'my', 'selfesteem', 'cuz', 'im', 'not', 'an', 'avid', 'signature', 'artist', 'like', 'herself', 'proud'], tags='INFJ'),
#  TaggedDocument(words=['banned', 'for', 'taking', 'all', 'the', 'room', 'under', 'my', 'bed', 'ya', 'gotta', 'learn', 'to', 'share', 'with', 'the', 'roaches'], tags='INFJ'),
#  TaggedDocument(words=[], tags='INFJ'),
#  TaggedDocument(words=['banned', 'for', 'being', 'too', 'much', 'of', 'thundering', 'grumbling', 'kind', 'of', 'storm', 'yep'], tags='INFJ'),
#  TaggedDocument(words=['ahh', 'old', 'high', 'school', 'music', 'havent', 'heard', 'in', 'ages'], tags='INFJ'),
#  TaggedDocument(words=['failed', 'public', 'speaking', 'class', 'few', 'years', 'ago', 'and', 'ive', 'sort', 'of', 'learned', 'what', 'could', 'do', 'better', 'were', 'to', 'be', 'in', 'that', 'position', 'again', 'big', 'part', 'of', 'my', 'failure', 'was', 'just', 'overloading', 'myself', 'with', 'too'], tags='INFJ'),
#  TaggedDocument(words=['like', 'this', 'persons', 'mentality', 'hes', 'confirmed', 'intj', 'by', 'the', 'way'], tags='INFJ'),
#  TaggedDocument(words=['move', 'to', 'the', 'denver', 'area', 'and', 'start', 'new', 'life', 'for', 'myself'], tags='INFJ'),
#  TaggedDocument(words=['im', 'finding', 'the', 'lack', 'of', 'me', 'in', 'these', 'posts', 'very', 'alarming'], tags='ENTP'),
#  TaggedDocument(words=['sex', 'can', 'be', 'boring', 'if', 'its', 'in', 'the', 'same', 'position', 'often', 'for', 'example', 'me', 'and', 'my', 'girlfriend', 'are', 'currently', 'in', 'an', 'environment', 'where', 'we', 'have', 'to', 'creatively', 'use', 'cowgirl', 'and', 'missionary', 'there', 'isnt', 'enough'], tags='ENTP'),
#  TaggedDocument(words=['giving', 'new', 'meaning', 'to', 'game', 'theory'], tags='ENTP'),
#  TaggedDocument(words=['hello', 'entp', 'grin', 'thats', 'all', 'it', 'takes', 'than', 'we', 'converse', 'and', 'they', 'do', 'most', 'of', 'the', 'flirting', 'while', 'acknowledge', 'their', 'presence', 'and', 'return', 'their', 'words', 'with', 'smooth', 'wordplay', 'and', 'more', 'cheeky', 'grins'], tags='ENTP'),
#  TaggedDocument(words=['this', 'lack', 'of', 'balance', 'and', 'hand', 'eye', 'coordination'], tags='ENTP'),
#  TaggedDocument(words=['real', 'iq', 'test', 'score', 'internet', 'iq', 'tests', 'are', 'funny', 'score', 'or', 'higher', 'now', 'like', 'the', 'former', 'responses', 'of', 'this', 'thread', 'will', 'mention', 'that', 'dont', 'believe', 'in', 'the', 'iq', 'test', 'before', 'you', 'banish'], tags='ENTP'),
#  TaggedDocument(words=['you', 'know', 'youre', 'an', 'entp', 'when', 'you', 'vanish', 'from', 'site', 'for', 'year', 'and', 'half', 'return', 'and', 'find', 'people', 'are', 'still', 'commenting', 'on', 'your', 'posts', 'and', 'liking', 'your', 'ideasthoughts', 'you', 'know', 'youre', 'an', 'entp', 'when', 'you'], tags='ENTP'),
#  TaggedDocument(words=[], tags='ENTP'),
#  TaggedDocument(words=[], tags='ENTP'),
#  TaggedDocument(words=['over', 'think', 'things', 'sometimes', 'go', 'by', 'the', 'old', 'sherlock', 'holmes', 'quote', 'perhaps', 'when', 'man', 'has', 'special', 'knowledge', 'and', 'special', 'powers', 'like', 'my', 'own', 'it', 'rather', 'encourages', 'him', 'to', 'seek', 'complex'], tags='ENTP'),
#  TaggedDocument(words=['so', 'is'], tags='ENTP'),
#  TaggedDocument(words=['post'], tags='ENTP'),
#  TaggedDocument(words=['not', 'really', 'ive', 'never', 'thought', 'of', 'ei', 'or', 'jp', 'as', 'real', 'functions', 'judge', 'myself', 'on', 'what', 'use', 'use', 'ne', 'and', 'ti', 'as', 'my', 'dominates', 'fe', 'for', 'emotions', 'and', 'rarely', 'si', 'also', 'use', 'ni', 'due', 'to', 'me', 'strength'], tags='ENTP'),
#  TaggedDocument(words=['you', 'know', 'though', 'that', 'was', 'ingenious', 'after', 'saying', 'it', 'really', 'want', 'to', 'try', 'it', 'and', 'see', 'what', 'happens', 'with', 'me', 'playing', 'first', 'person', 'shooter', 'in', 'the', 'back', 'while', 'we', 'drive', 'around', 'want', 'to', 'see', 'the', 'look', 'on'], tags='ENTP'),
#  TaggedDocument(words=['out', 'of', 'all', 'of', 'them', 'the', 'rock', 'paper', 'one', 'is', 'the', 'best', 'it', 'makes', 'me', 'lol', 'you', 'guys', 'are', 'lucky', 'im', 'really', 'high', 'up', 'on', 'the', 'tumblr', 'system'], tags='ENTP'),
#  TaggedDocument(words=['so', 'did', 'you', 'hear', 'about', 'that', 'new', 'first', 'person', 'shooter', 'game', 'ive', 'been', 'rocking', 'the', 'hell', 'out', 'of', 'the', 'soundtrack', 'on', 'my', 'auto', 'sound', 'equipment', 'that', 'will', 'shake', 'the', 'heavens', 'we', 'managed', 'to', 'put', 'couple', 'pss', 'in'], tags='ENTP'),
#  TaggedDocument(words=['no', 'the', 'way', 'he', 'connected', 'things', 'was', 'very', 'ne', 'ne', 'dominates', 'are', 'just', 'as', 'aware', 'of', 'their', 'environments', 'as', 'se', 'dominates', 'example', 'shawn', 'spencer', 'or', 'patrick', 'jane', 'both', 'entps'], tags='ENTP'),
#  TaggedDocument(words=['well', 'charlie', 'will', 'be', 'the', 'first', 'to', 'admit', 'do', 'get', 'jealous', 'like', 'you', 'do', 'chalk', 'it', 'up', 'to', 'my', 'heart', 'mixed', 'with', 'my', 'dominate', 'and', 'both', 'like', 'to', 'be', 'noticed', 'like', 'to', 'be', 'known', 'not', 'the', 'same'], tags='ENTP'),
#  TaggedDocument(words=['ill', 'upload', 'the', 'same', 'clip', 'with', 'the', 'mic', 'away', 'from', 'my', 'mouth', 'than', 'you', 'wont', 'hear', 'anything', 'ninja', 'assassin', 'style', 'but', 'with', 'splatter'], tags='ENTP'),
#  TaggedDocument(words=['tik', 'tok', 'is', 'really', 'great', 'song', 'as', 'long', 'as', 'you', 'can', 'mental', 'block', 'out', 'the', 'singer', 'love', 'the', 'beat', 'it', 'makes', 'me', 'bounce'], tags='ENTP'),
#  TaggedDocument(words=['dropio', 'vswck', 'mic', 'really', 'close', 'to', 'my', 'mouth', 'and', 'smokin', 'aces', 'assassins', 'ball', 'playing', 'in', 'the', 'background'], tags='ENTP'),
#  TaggedDocument(words=['sociable', 'extrovert', 'im', 'an', 'extrovert', 'and', 'im', 'not', 'sociable'], tags='ENTP'),
#  TaggedDocument(words=['sherlock', 'in', 'the', 'movie', 'was', 'an', 'entp', 'normally', 'hes', 'played', 'as', 'extj', 'in', 'the', 'books', 'hes', 'an', 'estj', 'as', 'said', 'the', 'movie', 'looked', 'good', 'except', 'for', 'it', 'being', 'called', 'sherlock', 'holmes'], tags='ENTP'),
#  TaggedDocument(words=[], tags='ENTP'),
#  TaggedDocument(words=['oh', 'never', 'had', 'fear', 'of', 'kissing', 'guy', 'will', 'kiss', 'an', 'animal', 'too', 'so', 'there', 'was', 'nothing', 'to', 'vanish', 'just', 'personal', 'taste', 'and', 'me', 'not', 'liking', 'it', 'the', 'guy', 'kissed', 'didnt', 'know', 'me', 'it', 'was', 'one', 'of', 'those'], tags='ENTP'),
#  TaggedDocument(words=['sounds', 'pretty', 'much', 'like', 'my', 'area', 'and', 'what', 'im', 'going', 'through', 'right', 'now', 'trying', 'to', 'figure', 'out', 'which', 'way', 'want', 'to', 'take', 'my', 'life', 'want', 'to', 'do', 'so', 'many', 'things', 'the', 'biggest', 'problem', 'is', 'that', 'know', 'if', 'dont'], tags='ENTP'),
#  TaggedDocument(words=['was', 'operating', 'under', 'the', 'impression', 'that', 'you', 'were', 'female', 'never', 'looked', 'at', 'your', 'boxy', 'okay', 'help', 'out', 'my', 'gay', 'friends', 'all', 'the', 'time', 'and', 'one', 'of', 'them', 'has', 'developed', 'little', 'crush', 'on', 'me', 'get', 'red'], tags='ENTP'),
#  TaggedDocument(words=['tt', 'you', 'just', 'described', 'me', 'and', 'im', 'living', 'the', 'worst', 'nightmare', 'im', 'trapped', 'in', 'one', 'place', 'with', 'one', 'one', 'around', 'only', 'dull', 'woods', 'if', 'was', 'serial', 'killer', 'this', 'would', 'be', 'the', 'perfect', 'place', 'but', 'sadly', 'im'], tags='ENTP'),
#  TaggedDocument(words=['tbh', 'and', 'biased', 'sounds', 'like', 'shadowed', 'infp', 'think', 'maybe', 'he', 'was', 'hurt', 'and', 'turned', 'estj', 'can', 'tell', 'because', 'he', 'has', 'some', 'of', 'the', 'typical', 'infp', 'traits', 'left', 'over'], tags='ENTP'),
#  TaggedDocument(words=['checks', 'list', 'im', 'sorry', 'it', 'seems', 'that', 'you', 'have', 'came', 'at', 'bad', 'time', 'weve', 'already', 'reached', 'our', 'quota', 'of', 'infjs', 'however', 'being', 'youre', 'female', 'and', 'like', 'females', 'will', 'make', 'you', 'deal', 'will', 'kick', 'one'], tags='ENTP'),
#  TaggedDocument(words=['im', 'antp', 'leaning', 'toward', 'im', 'easy', 'for', 'both', 'entps', 'and', 'intps', 'to', 'identify', 'with'], tags='ENTP'),
#  TaggedDocument(words=['also', 'imagine', 'entps', 'interrogations', 'would', 'go', 'little', 'bit', 'like', 'jacks', 'from', 'except', 'more', 'mechanical', 'rigging', 'up', 'shock', 'treatment', 'equipment', 'in', 'an', 'abandoned', 'building', 'out', 'of', 'an', 'old', 'car', 'batty', 'jumper'], tags='ENTP'),
#  TaggedDocument(words=['it', 'was', 'compliment', 'trust', 'me', 'im', 'just', 'as', 'psychopathic', 'except', 'have', 'emoticons', 'theyre', 'just', 'weird', 'ones', 'like', 'laughing', 'when', 'get', 'hurt', 'or', 'at', 'people', 'running', 'themselves', 'over', 'with', 'their', 'lawn', 'mower'], tags='ENTP'),
#  TaggedDocument(words=[], tags='ENTP'),
#  TaggedDocument(words=['no', 'its', 'like', 'theme', 'for', 'where', 'live', 'and', 'that', 'is', 'why', 'know', 'it', 'by', 'heart'], tags='ENTP'),
#  TaggedDocument(words=['and', 'usual', 'dont', 'leave', 'until', 'the', 'thing', 'ends', 'but', 'in', 'the', 'mean', 'time', 'in', 'between', 'times', 'you', 'work', 'your', 'thing', 'ill', 'work', 'mine', 'im', 'the', 'mbp', 'pleasure', 'to', 'meet', 'you'], tags='ENTP'),
#  TaggedDocument(words=['damn', 'need', 'to', 'trust', 'my', 'instincts', 'more', 'would', 'have', 'been', 'closer', 'was', 'going', 'to', 'say', 'infp'], tags='ENTP'),
#  TaggedDocument(words=['exfp', 'leaning', 'toward', 'with', 'the', 'way', 'she', 'responded', 'my', 'friends', 'even', 'my', 'gay', 'and', 'lesbian', 'ones', 'always', 'come', 'to', 'me', 'for', 'advice'], tags='ENTP'),
#  TaggedDocument(words=['bow', 'to', 'my', 'tokentype', 'masters', 'entps', 'are', 'so', 'great', 'if', 'it', 'wasnt', 'for', 'entps', 'wouldnt', 'have', 'been', 'able', 'to', 'build', 'what', 'im', 'building', 'duck', 'duck', 'duck', 'shotgun'], tags='ENTP'),
#  TaggedDocument(words=['what', 'me', 'never', 'do', 'that'], tags='ENTP'),
#  TaggedDocument(words=['because', 'its', 'hard', 'to', 'be', 'sad', 'about', 'losing', 'someone', 'you', 'like', 'when', 'you', 'knew', 'you', 'were', 'right', 'and', 'give', 'yourself', 'big', 'pat', 'on', 'the', 'back', 'because', 'youre', 'awesome', 'and', 'always', 'correct'], tags='ENTP'),
#  TaggedDocument(words=['oh', 'you', 'dont', 'have', 'to', 'tell', 'me', 'that', 'most', 'of', 'them', 'are', 'stupid', 'know', 'this', 'that', 'is', 'why', 'play', 'with', 'them', 'and', 'it', 'makes', 'me', 'laugh', 'as', 'im', 'going', 'to', 'take', 'neuropsychology', 'and', 'have', 'few', 'psychologist'], tags='ENTP'),
#  TaggedDocument(words=['im', 'nightowl', 'wake', 'up', 'between', 'pm', 'and', 'stay', 'awake', 'till', 'am'], tags='ENTP'),
#  TaggedDocument(words=['personal', 'opinion', 'backed', 'by', 'theory', 'would', 'suggest', 'that', 'intps', 'are', 'the', 'most', 'socially', 'difficult', 'while', 'intjs', 'can', 'be', 'socially', 'indifferent', 'but', 'they', 'will', 'also', 'use', 'social', 'situations', 'if', 'the', 'the', 'need', 'arises'], tags='ENTP'),
#  TaggedDocument(words=['personal', 'stocks', 'that', 'have', 'on', 'my', 'desktop', 'that', 'ive', 'downloaded', 'from', 'random', 'stock', 'sites', 'and', 'stock', 'photobuckets'], tags='ENTP'),
#  TaggedDocument(words=['ill', 'tell', 'you', 'when', 'open', 'photoshop', 'glad', 'you', 'like', 'it', 'static'], tags='ENTP'),
#  TaggedDocument(words=['thanks'], tags='ENTP'),
#  TaggedDocument(words=['made', 'for', 'friend', 'several', 'hours', 'of', 'work', 'constructed', 'every', 'line', 'by'], tags='ENTP'),
#  TaggedDocument(words=['static', 'ill', 'have', 'to', 'get', 'to', 'your', 'avatar', 'later', 'if', 'one', 'of', 'my', 'fellow', 'teammates', 'doesnt'], tags='ENTP'),
#  TaggedDocument(words=['psychologist', 'dont', 'keep', 'me', 'around', 'long', 'enough', 'to', 'diagnosis', 'me', 'like', 'to', 'toy', 'with', 'them', 'what', 'have', 'diagnosis', 'myself', 'with', 'and', 'had', 'few', 'psychologist', 'friends', 'few', 'other', 'friends', 'tell', 'me', 'have', 'is'], tags='ENTP'),
#  TaggedDocument(words=['good', 'one'], tags='INTP'),
#  TaggedDocument(words=['of', 'course', 'to', 'which', 'say', 'know', 'thats', 'my', 'blessing', 'and', 'my', 'curse'], tags='INTP'),
#  TaggedDocument(words=['does', 'being', 'absolutely', 'positive', 'that', 'you', 'and', 'your', 'best', 'friend', 'could', 'be', 'an', 'amazing', 'couple', 'count', 'if', 'so', 'than', 'yes', 'or', 'its', 'more', 'could', 'be', 'madly', 'in', 'love', 'in', 'case', 'reconciled', 'my', 'feelings', 'which', 'at'], tags='INTP'),
#  TaggedDocument(words=['no', 'didnt', 'thank', 'you', 'for', 'link'], tags='INTP'),
#  TaggedDocument(words=['socalled', 'tisi', 'loop', 'and', 'it', 'can', 'stem', 'from', 'any', 'current', 'topicobsession', 'can', 'be', 'deadly', 'its', 'like', 'when', 'youre', 'stuck', 'in', 'your', 'own', 'thoughts', 'and', 'your', 'mind', 'just', 'wanders', 'in', 'circles', 'feels', 'truly', 'terrible'], tags='INTP'),
#  TaggedDocument(words=['have', 'you', 'noticed', 'how', 'peculiar', 'vegetation', 'can', 'be', 'all', 'you', 'have', 'to', 'do', 'is', 'look', 'down', 'at', 'the', 'grass', 'dozens', 'of', 'different', 'plant', 'species', 'there', 'and', 'now', 'imagine', 'that', 'hundreds', 'of', 'years', 'later', 'whenif', 'soil'], tags='INTP'),
#  TaggedDocument(words=['the', 'smiths', 'never', 'had', 'no', 'one', 'ever'], tags='INTP'),
#  TaggedDocument(words=['often', 'find', 'myself', 'spotting', 'faces', 'on', 'marble', 'tileswood'], tags='INTP'),
#  TaggedDocument(words=['this', 'yearold', 'sentence', 'is', 'an', 'incredibly', 'accurate', 'and', 'beautiful', 'description'], tags='INTP'),
#  TaggedDocument(words=['havent', 'visited', 'this', 'website', 'in', 'the', 'last', 'years', 'so', 'whoever', 'reads', 'this', 'and', 'maybe', 'even', 'remembers', 'me', 'which', 'highly', 'doubt', 'hi'], tags='INTP'),
#  TaggedDocument(words=['when', 'you', 'sit', 'in', 'your', 'garden', 'until', 'pm', 'writing', 'songs', 'and', 'sing', 'them', 'together', 'with', 'dozens', 'of', 'crickets', 'while', 'playing', 'your', 'acoustic', 'guitar'], tags='INTP'),
#  TaggedDocument(words=['this', 'is', 'the', 'most', 'intpish', 'thread', 'ive', 'ever', 'seen'], tags='INTP'),
#  TaggedDocument(words=['wouldnt', 'be', 'able', 'to', 'look', 'at', 'the', 'painting', 'for', 'the', 'entire', 'life', 'if', 'knew', 'that', 'picked', 'it', 'over', 'the', 'human', 'being'], tags='INTP'),
#  TaggedDocument(words=['was', 'drawing', 'background', 'for', 'my', 'animation', 'on', 'which', 'im', 'working', 'right', 'now', 'it', 'should', 'have', 'been', 'mars', 'but', 'felt', 'obligated', 'to', 'make', 'mark', 'watneyxs', 'postcard', 'from', 'it', 'if', 'you', 'read', 'the', 'book'], tags='INTP'),
#  TaggedDocument(words=['started', 'to', 'make', 'comics', 'about', 'turtle', 'gordon', 'and', 'unicorn', 'chimes', 'here', 'you', 'can', 'see', 'two', 'first', 'stories'], tags='INTP'),
#  TaggedDocument(words=['intj', 'recently', 'started', 'to', 'post', 'my', 'comics', 'about', 'two', 'friends', 'turtle', 'gordon', 'and', 'unicorn', 'chimes', 'before', 'that', 'just', 'posted', 'stuff', 'that', 'interested', 'me', 'but', 'from', 'now', 'on', 'ill', 'try', 'to', 'include', 'only', 'my', 'works'], tags='INTP'),
#  TaggedDocument(words=['probably', 'we', 'could', 'work', 'together', 'on', 'new', 'model', 'im', 'an', 'expert', 'in', 'abrupt', 'explosions', 'of', 'laughter', 'upon', 'various', 'weird', 'stuff', 'that', 'happens', 'because', 'of', 'peculiar', 'sense', 'of', 'humor', 'so', 'peculiar', 'that', 'not', 'much'], tags='INTP'),
#  TaggedDocument(words=['hell'], tags='INTP'),
#  TaggedDocument(words=['well', 'kind', 'of', 'as', 'it', 'was', 'already', 'mentioned', 'sometimes', 'because', 'of', 'ni', 'its', 'hard', 'to', 'convey', 'complex', 'stuff', 'which', 'pops', 'up', 'in', 'your', 'head', 'in', 'whimsical', 'compilations', 'of', 'shapes', 'and', 'pictures', 'only', 'with', 'words'], tags='INTP'),
#  TaggedDocument(words=['think', 'this', 'kitten', 'would', 'be', 'very', 'appropriate', 'here'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['good', 'night', 'everyone', 'out', 'there', 'even', 'if', 'for', 'someone', 'there', 'is', 'morning', 'right', 'now', 'nights', 'always', 'supersede', 'mornings', 'and', 'people', 'say', 'good', 'night', 'in', 'order', 'to', 'meet', 'next', 'day'], tags='INTP'),
#  TaggedDocument(words=['oh', 'that', 'movie', 'its', 'awesome', 'thank', 'you', 'hope', 'you', 'had', 'good', 'sleep', 'in', 'the', 'air', 'anyway', 'im', 'wishing', 'you', 'good', 'night', 'for', 'the', 'next', 'night', 'ahead', 'hopefully', 'it', 'will', 'be', 'on', 'land', 'good', 'people', 'deserve', 'good'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['well', 'other', 'people', 'who', 'may', 'be', 'wondering', 'about', 'an', 'issue', 'from', 'the', 'name', 'of', 'the', 'topic', 'will', 'find', 'your', 'response', 'helpful', 'anyway'], tags='INTP'),
#  TaggedDocument(words=['this', 'finally', 'someone', 'mentioned', 'that'], tags='INTP'),
#  TaggedDocument(words=['still', 'see', 'creaturesfaces', 'in', 'maze', 'of', 'various', 'random', 'patterns', 'it', 'can', 'be', 'amusing', 'sometimes', 'its', 'very', 'handy', 'skill', 'when', 'youre', 'bored'], tags='INTP'),
#  TaggedDocument(words=['oh', 'didnt', 'know', 'that', 'what', 'pity', 'why', 'not', 'sacrifice', 'whole', 'supermarket', 'then', 'we', 'can', 'decide', 'which', 'walmart', 'will', 'be', 'the', 'best', 'think', 'the', 'biggest', 'one', 'would', 'be', 'great'], tags='INTP'),
#  TaggedDocument(words=['yippy', 'here', 'you', 'go', 'he', 'thinks', 'that', 'the', 'fire', 'is', 'delicious', 'should', 'sacrifice', 'tofu', 'dont', 'like', 'to', 'waste', 'food'], tags='INTP'),
#  TaggedDocument(words=['dont', 'think', 'that', 'the', 'creator', 'of', 'this', 'thread', 'cares', 'whats', 'going', 'on', 'here', 'after', 'years'], tags='INTP'),
#  TaggedDocument(words=['heh', 'understand', 'you', 'with', 'these', 'same', 'given', 'languages'], tags='INTP'),
#  TaggedDocument(words=['ye'], tags='INTP'),
#  TaggedDocument(words=['get', 'angry', 'quite', 'rarely', 'but', 'when', 'do', 'its', 'safer', 'for', 'surrounding', 'people', 'to', 'go', 'somewhere', 'else', 'its', 'impossible', 'for', 'me', 'to', 'hide', 'or', 'suppress', 'anger', 'the', 'only', 'way', 'to', 'get', 'rid', 'of', 'this', 'feeling', 'is', 'to', 'burst'], tags='INTP'),
#  TaggedDocument(words=['ive', 'never', 'liked', 'it', 'anything', 'fake', 'is', 'bad', 'actually'], tags='INTP'),
#  TaggedDocument(words=['hugs', 'should', 'be', 'given', 'only', 'to', 'chosen', 'ones', 'chosen', 'there', 'are', 'quite', 'few', 'of', 'them', 'though'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['yup', 'youre', 'doing', 'it', 'right'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['of', 'course', 'its', 'not', 'very', 'comfortable', 'but', 'human', 'race', 'survived', 'thankfully', 'womens', 'ability', 'to', 'give', 'birth', 'to', 'other', 'human', 'beings', 'it', 'worked', 'for', 'thousands', 'of', 'years', 'why', 'change', 'it', 'besides', 'there', 'are'], tags='INTP'),
#  TaggedDocument(words=['that', 'happens', 'and', 'it', 'occurs', 'because', 'most', 'often', 'people', 'use', 'results', 'of', 'extremely', 'precise', 'and', 'elaborate', 'online', 'tests', 'as', 'basis', 'of', 'determining', 'ones', 'type', 'both', 'visual', 'and', 'language', 'arts', 'more'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['study', 'graphic', 'design', 'now', 'which', 'really', 'enjoy', 'what', 'is', 'interesting', 'about', 'this', 'field', 'is', 'that', 'the', 'ability', 'to', 'generate', 'ideas', 'and', 'solve', 'problems', 'is', 'much', 'more', 'important', 'than', 'possession', 'of', 'specific'], tags='INTP'),
#  TaggedDocument(words=['ale'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['am', 'always', 'ready', 'to', 'discipline', 'to', 'intimidate', 'to', 'be', 'precise', 'my', 'siblings', 'offender'], tags='INTP'),
#  TaggedDocument(words=['world', 'domination', 'shooting', 'people', 'in', 'the', 'head', 'why', 'oh', 'right', 'intjs', 'always', 'must', 'be', 'characterised', 'only', 'with', 'these', 'words', 'want', 'to', 'show', 'so', 'badly', 'my', 'reaction', 'to', 'this'], tags='INTP'),
#  TaggedDocument(words=[], tags='INTP'),
#  TaggedDocument(words=['istp'], tags='INTP'),
#  TaggedDocument(words=['dear', 'intp', 'enjoyed', 'our', 'conversation', 'the', 'other', 'day', 'esoteric', 'gabbing', 'about', 'the', 'nature', 'of', 'the', 'universe', 'and', 'the', 'idea', 'that', 'every', 'rule', 'and', 'social', 'code', 'being', 'arbitrary', 'constructs', 'created'], tags='INTJ'),
#  TaggedDocument(words=['dear', 'entj', 'sub', 'long', 'time', 'no', 'see', 'sincerely', 'alpha'], tags='INTJ'),
#  TaggedDocument(words=['none', 'of', 'them', 'all', 'other', 'types', 'hurt', 'in', 'deep', 'existential', 'ways', 'that', 'want', 'no', 'part', 'of'], tags='INTJ'),
#  TaggedDocument(words=['probably', 'sliding', 'scale', 'that', 'depends', 'on', 'individual', 'preferences', 'like', 'everything', 'in', 'humanity'], tags='INTJ'),
#  TaggedDocument(words=['draco', 'malfoy', 'also', 'id', 'say', 'hes', 'either', 'or'], tags='INTJ'),
#  TaggedDocument(words=['im', 'either', 'or', 'though', 'in', 'which', 'stacking', 'to', 'me', 'is', 'somewhat', 'arbitrary', 'distinction', 'to', 'make', 'as', 'believe', 'that', 'the', 'core', 'indicates', 'primary', 'motivation', 'and', 'has', 'hand', 'in', 'every', 'action', 'therefore'], tags='INTJ'),
#  TaggedDocument(words=['im', 'not', 'particularly', 'introverted', 'or', 'extraverted', 'personally', 'that', 'said', 'would', 'say', 'im', 'somewhat', 'unphased', 'by', 'either', 'social', 'interactions', 'or', 'being', 'alone', 'what', 'id', 'say', 'crave', 'more', 'so', 'than', 'anything', 'is'], tags='INTJ'),
#  TaggedDocument(words=['dear', 'type', 'infp', 'your', 'absolute', 'admiration', 'of', 'me', 'is', 'refreshing', 'youre', 'great', 'girlfriend', 'and', 'wish', 'we', 'both', 'didnt', 'have', 'such', 'busy', 'schedules', 'so', 'we', 'could', 'be', 'around', 'one', 'another', 'more', 'often', 'keep'], tags='INTJ'),
#  TaggedDocument(words=['still', 'means', 'about', 'people', 'ive', 'probably', 'seen', 'others', 'today', 'never', 'understood', 'fascination', 'by', 'virtue', 'of', 'rarity'], tags='INTJ'),
#  TaggedDocument(words=['so', 'youre', 'on', 'the', 'esfj', 'train', 'also', 'right'], tags='INTJ'),
#  TaggedDocument(words=['have', 'toyed', 'with', 'the', 'idea', 'of', 'the', 'op', 'being', 'an', 'extrovert', 'also', 'for', 'awhile', 'now', 'actually', 'after', 'many', 'conversations', 'with', 'him', 'however', 'im', 'disinclined', 'to', 'believe', 'it', 'due', 'to', 'op', 'being', 'much', 'too', 'close', 'with', 'fi'], tags='INTJ'),
#  TaggedDocument(words=['still', 'esfj'], tags='INTJ'),
#  TaggedDocument(words=['disagree', 'definite', 'esfj', 'fe', 'si', 'all', 'up', 'in', 'this'], tags='INTJ'),
#  TaggedDocument(words=['where', 'have', 'you', 'been', 'your', 'mother', 'and', 'have', 'been', 'worried', 'sick'], tags='INTJ'),
#  TaggedDocument(words=['similar', 'feelings', 'concerning', 'entps'], tags='INTJ'),
#  TaggedDocument(words=['collect', 'shoes', 'do', 'so', 'because', 'like', 'status', 'and', 'nothing', 'communicates', 'such', 'thing', 'as', 'much', 'as', 'pair', 'of', 'jordans'], tags='INTJ'),
#  TaggedDocument(words=['sure', 'lets', 'get', 'weird', 'back', 'off'], tags='INTJ'),
#  TaggedDocument(words=['best'], tags='INTJ'),
#  TaggedDocument(words=['insert', 'other', 'into', 'previous', 'post'], tags='INTJ'),
#  TaggedDocument(words=['wow', 'dont', 'nobody', 'got', 'time', 'fo', 'dat', 'jk', 'kno', 'mah', 'boi'], tags='INTJ'),
#  TaggedDocument(words=['well', 'as', 'im', 'sure', 'everyone', 'knows', 'being', 'social', 'primary', 'doesnt', 'necessarily', 'equal', 'being', 'social', 'like', 'other', 'people', 'just', 'fine', 'but', 'lately', 'ive', 'been', 'on', 'bit', 'of', 'break', 'when', 'it', 'comes', 'to', 'my'], tags='INTJ'),
#  TaggedDocument(words=['thats', 'pretty', 'crappy', 'of', 'her', 'your', 'sex', 'life', 'is', 'definitely', 'not', 'her', 'business', 'if', 'were', 'you', 'id', 'definitely', 'talk', 'to', 'her', 'about', 'it'], tags='INTJ'),
#  TaggedDocument(words=['yeah', 'had', 'lot', 'longer', 'to', 'think', 'about', 'it', 'that', 'said', 'dont', 'think', 'youre', 'te', 'so', 'if', 'we', 'operate', 'under', 'the', 'assumptions', 'in', 'the', 'op', 'youre', 'infj', 'because', 'nothing', 'else', 'makes', 'sense', 'im', 'not', 'saying'], tags='INTJ'),
#  TaggedDocument(words=['whether', 'or', 'not', 'you', 'actually', 'are', 'your', 'mom', 'makes', 'fun', 'of', 'you', 'for', 'being', 'virgin', 'is', 'this', 'playful', 'teasing'], tags='INTJ'),
#  TaggedDocument(words=['just', 'stab', 'in', 'the', 'dark', 'here', 'dont', 'think', 'thats', 'te', 'under', 'the', 'hood', 'if', 'this', 'here', 'is', 'all', 'im', 'given', 'to', 'work', 'with', 'id', 'have', 'to', 'say', 'infj', 'compare', 'your', 'idea', 'of', 'logic', 'to', 'mine', 'logic', 'is', 'series', 'of'], tags='INTJ'),
#  TaggedDocument(words=['what', 'makes', 'the', 'most', 'sense'], tags='INTJ'),
#  TaggedDocument(words=['tentatively', 'intj', 'still', 'reading', 'edit', 'so', 'far', 'am', 'of', 'the', 'belief', 'that', 'youre', 'most', 'of', 'the', 'things', 'you', 'say', 'you', 'are', 'appreciate', 'the', 'level', 'of', 'detail', 'edit', 'also', 'relatively', 'certain', 'you', 'are', 'ni'], tags='INTJ'),
#  TaggedDocument(words=['refreshing', 'self', 'with', 'reading', 'about', 'instinctual', 'variants', 'god', 'im', 'hard', 'social', 'type'], tags='INTJ'),
#  TaggedDocument(words=['wow', 'useful', 'thought', 'you', 'had', 'there', 'wanna', 'know', 'what', 'my', 'favorite', 'part', 'was', 'the', 'fact', 'that', 'it', 'ended'], tags='INTJ'),
#  TaggedDocument(words=['am', 'both', 'annoyed', 'and', 'intrigued', 'by', 'xxfps', 'as', 'far', 'as', 'can', 'tell', 'dislike', 'all', 'types', 'in', 'my', 'normal', 'life'], tags='INTJ'),
#  TaggedDocument(words=['im', 'not', 'of', 'the', 'mind', 'that', 'any', 'enneatypembti', 'combination', 'is', 'impossible', 'because', 'cognition', 'the', 'things', 'that', 'motivate', 'us', 'that', 'said', 'we', 'can', 'clearly', 'observe', 'many', 'types', 'being', 'more', 'common', 'than', 'others'], tags='INTJ'),
#  TaggedDocument(words=['sx', 'as', 'hell'], tags='INTJ'),
#  TaggedDocument(words=['very', 'seriously', 'toying', 'with', 'the', 'idea', 'of', 'being', 'can', 'be', 'pretty', 'aggressive', 'and', 'controlling', 'but', 'have', 'massive', 'holier', 'than', 'thou', 'streak', 'once', 'you', 'get', 'to', 'know', 'me', 'with', 'any', 'depth', 'like', 'more', 'than'], tags='INTJ'),
#  TaggedDocument(words=['id', 'say', 'its', 'mostly', 'emotional', 'experience'], tags='INTJ'),
#  TaggedDocument(words=['because', 'find', 'in', 'depth', 'study', 'of', 'cognition', 'more', 'interesting', 'included', 'mbti', 'in', 'my', 'answer', 'to', 'illustrate', 'how', 'much', 'enjoyed', 'socionics', 'interpret', 'the', 'post', 'as', 'wholehearted', 'agreement', 'with', 'what', 'she', 'was'], tags='INTJ'),
#  TaggedDocument(words=['no', 'real', 'argument', 'here', 'know', 'what', 'am', 'and', 'what', 'am', 'is', 'an', 'asshole', 'that', 'is', 'for', 'second', 'baring', 'his', 'teeth', 'at', 'the', 'people', 'that', 'seemingly', 'have', 'lot', 'to', 'say', 'but', 'refuse', 'to', 'address', 'me', 'beyond', 'single'], tags='INTJ'),
#  TaggedDocument(words=['would', 'refer', 'you', 'to', 'the', 'op', 'if', 'you', 'need', 'literal', 'analysis', 'im', 'happy', 'to', 'provide', 'it', 'that', 'said', 'im', 'going', 'to', 'assume', 'youre', 'able', 'to', 'read', 'and', 'interpret', 'symbolism', 'so', 'doubt', 'youll', 'need', 'that', 'much', 'help'], tags='INTJ'),
#  TaggedDocument(words=['and', 'this', 'was', 'sort', 'of', 'my', 'thought', 'process', 'the', 'initial', 'post', 'and', 'how', 'it', 'connects', 'the', 'generally', 'accepted', 'view', 'of', 'the', 'type', 'and', 'what', 'the', 'type', 'is', 'motivated', 'by', 'doesnt', 'seem', 'to', 'be', 'in', 'need', 'of', 'explanation'], tags='INTJ'),
#  TaggedDocument(words=['oh', 'my', 'am', 'quite', 'crushable', 'huh', 'back', 'atcha'], tags='INTJ'),
#  TaggedDocument(words=['was', 'but', 'its', 'am', 'ill', 'take', 'what', 'can', 'get'], tags='INTJ'),
#  TaggedDocument(words=['wanted', 'to', 'come', 'up', 'with', 'something', 'clever', 'but', 'its', 'almost', 'am', 'would', 'give', 'you', 'lot', 'of', 'sex'], tags='INTJ'),
#  TaggedDocument(words=['so', 'then', 'why', 'do', 'you', 'even', 'bother', 'asking', 'if', 'youve', 'already', 'made', 'up', 'your', 'mind', 'that', 'you', 'are', 'an', 'extravert', 'intuitive', 'and', 'feeling', 'if', 'youve', 'already', 'decided', 'you', 'are', 'these', 'things', 'and', 'have', 'evidently', 'done', 'the'], tags='INTJ'),
#  TaggedDocument(words=['wasnt', 'sure', 'listened', 'to', 'sx', 'music', 'until', 'now'], tags='INTJ'),
#  TaggedDocument(words=['infp', 'messaged', 'me', 'with', 'picture', 'of', 'herself', 'before', 'going', 'to', 'bed', 'asked', 'me', 'to', 'say', 'goodnight', 'to', 'her', 'asked', 'me', 'to', 'say', 'goodnight', 'to', 'her', 'again', 'did', 'thought', 'it', 'was', 'weird', 'secretly', 'like'], tags='INTJ'),
#  TaggedDocument(words=['either', 'way', 'you', 'see', 'my', 'point', 'the', 'actual', 'rarity', 'is', 'skewed', 'and', 'makes', 'type', 'seem', 'rarer', 'than', 'it', 'likely', 'is', 'in', 'real', 'contexts', 'may', 'have', 'been', 'the', 'only', 'one', 'of', 'my', 'type', 'in', 'class', 'room', 'in', 'high', 'school', 'but'], tags='INTJ'),
#  TaggedDocument(words=['wow', 'my', 'math', 'was', 'off', 'literally', 'just', 'said', 'numbers', 'see', 'how', 'over', 'glorified', 'the', 'type', 'is', 'even', 'so', 'though', 'saw', 'around', 'twohundred', 'people', 'really', 'rough', 'estimate', 'between', 'both', 'of', 'my', 'jobs', 'its'], tags='INTJ'),
#  TaggedDocument(words=['rarity', 'in', 'the', 'context', 'of', 'the', 'entire', 'planet', 'is', 'somewhat', 'silly', 'even', 'if', 'we', 'assume', 'the', 'greatest', 'reports', 'of', 'our', 'rarity', 'we', 'intj', 'encompass', 'of', 'the', 'planet', 'which', 'sounds', 'rare', 'when', 'you', 'dont', 'think'], tags='INTJ'),
#  TaggedDocument(words=['one', 'could', 'say', 'that', 'whatever', 'the', 'culmination', 'of', 'all', 'of', 'our', 'actions', 'are', 'throughout', 'our', 'lives', 'equal', 'our', 'potential', 'in', 'this', 'sense', 'everybody', 'does', 'but', 'as', 'we', 'all', 'know', 'not', 'everyones', 'potential', 'is', 'the'], tags='INTJ'),
#  TaggedDocument(words=['would', 'agree', 'however', 'those', 'that', 'profess', 'to', 'know', 'their', 'type', 'not', 'stating', 'anything', 'about', 'their', 'types', 'motivations', 'strike', 'me', 'as', 'either', 'not', 'wanting', 'to', 'touch', 'on', 'them', 'or', 'not', 'being', 'able', 'to', 'if', 'they', 'dont'], tags='INTJ'),
#  TaggedDocument(words=['lol'], tags='INTJ'),
#  TaggedDocument(words=['youre', 'fired'], tags='ENTJ'),
#  TaggedDocument(words=['thats', 'another', 'silly', 'misconception', 'that', 'approaching', 'is', 'logically', 'is', 'going', 'to', 'be', 'the', 'key', 'to', 'unlocking', 'whatever', 'it', 'is', 'you', 'think', 'you', 'are', 'entitled', 'to', 'nobody', 'wants', 'to', 'be', 'approached', 'with', 'bs'], tags='ENTJ'),
#  TaggedDocument(words=['but', 'guys', 'he', 'really', 'wants', 'to', 'go', 'on', 'vacation', 'cmon', 'guys', 'his', 'boss', 'just', 'doesnt', 'listen', 'or', 'get', 'it', 'he', 'even', 'approached', 'him', 'logically', 'and', 'everything'], tags='ENTJ'),
#  TaggedDocument(words=['never', 'mind', 'just', 'go', 'on', 'permanent', 'vacation'], tags='ENTJ'),
#  TaggedDocument(words=['two', 'months', 'wouldnt', 'be', 'crazy', 'about', 'the', 'idea', 'if', 'you', 'are', 'really', 'his', 'best', 'employee', 'then', 'thats', 'what', 'may', 'be', 'cooking', 'him', 'who', 'wants', 'their', 'most', 'reliable', 'asset', 'gone', 'for', 'that', 'long', 'entj', 'employer'], tags='ENTJ'),
#  TaggedDocument(words=['lol', 'its', 'not', 'like', 'our', 'views', 'were', 'unsolicited', 'what', 'victim'], tags='ENTJ'),
#  TaggedDocument(words=['sometimes', 'just', 'really', 'like', 'impoverished', 'rap', 'music'], tags='ENTJ'),
#  TaggedDocument(words=['probably', 'would', 'have', 'lost', 'it', 'too', 'his', 'stonewalling', 'was', 'insignificant', 'he', 'was', 'being', 'an', 'idiot', 'over', 'semantics', 'that', 'didnt', 'have', 'any', 'impact', 'on', 'anything', 'its', 'one', 'thing', 'to', 'stone', 'wall', 'on', 'critical', 'shit', 'but'], tags='ENTJ'),
#  TaggedDocument(words=['would', 'have', 'just', 'taken', 'the', 'project', 'and', 'gave', 'them', 'something', 'later'], tags='ENTJ'),
#  TaggedDocument(words=['the', 'court', 'deposition', 'wasnt', 'skit', 'that', 'actually', 'happened', 'it', 'was', 'verbatim', 'reenactment'], tags='ENTJ'),
#  TaggedDocument(words=['and', 'her', 'ass'], tags='ENTJ'),
#  TaggedDocument(words=['ill', 'flirt', 'woman', 'for', 'piece', 'of', 'candy', 'at', 'the', 'grocery', 'store', 'of', 'course', 'use', 'whatever', 'have', 'at', 'my', 'disposal', 'to', 'get', 'what', 'want', 'in', 'the', 'most', 'efficient', 'manner', 'possible', 'if', 'that', 'means', 'flirting', 'that'], tags='ENTJ'),
#  TaggedDocument(words=[], tags='ENTJ'),
#  TaggedDocument(words=['yes', 'in', 'the', 'comments', 'she', 'gave', 'more', 'info', 'then', 'was', 'shut', 'down', 'because', 'she', 'went', 'from', 'having', 'crush', 'on', 'her', 'boss', 'and', 'wanted', 'to', 'know', 'how', 'to', 'impress', 'him', 'to', 'her', 'boss', 'is', 'married', 'and', 'she', 'wasnt', 'interested'], tags='ENTJ'),
#  TaggedDocument(words=['whats', 'this', 'we', 'thing', 'about'], tags='ENTJ'),
#  TaggedDocument(words=['callaendia', 'are', 'you', 'the', 'same', 'infp', 'girl', 'who', 'was', 'on', 'the', 'entj', 'facebook', 'forum', 'with', 'this', 'similar', 'question', 'just', 'have', 'to', 'ask', 'because', 'the', 'times', 'are', 'so', 'close', 'together', 'and', 'the', 'scenario', 'is', 'so', 'similar'], tags='ENTJ'),
#  TaggedDocument(words=[], tags='ENTJ'),
#  TaggedDocument(words=['do', 'not', 'modify', 'myself', 'to', 'suit', 'others', 'however', 'do', 'like', 'the', 'spotlight'], tags='ENTJ'),
#  TaggedDocument(words=['think', 'the', 'easiest', 'and', 'most', 'efficient', 'approach', 'is', 'tarp', 'jigsaw', 'and', 'mulcher', 'but', 'thats', 'just', 'my', 'personal', 'preference', 'not', 'all', 'entjs', 'are', 'the', 'same'], tags='ENTJ'),
#  TaggedDocument(words=['just', 'dont', 'hump', 'my', 'leg'], tags='ENTJ'),
#  TaggedDocument(words=['what', 'are', 'you', 'like', 'chihuahua', 'or', 'some', 'shit'], tags='ENTJ'),
#  TaggedDocument(words=['once', 'dumped', 'girl', 'in', 'college', 'who', 'was', 'having', 'month', 'romp', 'with', 'over', 'making', 'me', 'late', 'for', 'class', 'she', 'said', 'was', 'petty', 'for', 'it'], tags='ENTJ'),
#  TaggedDocument(words=['dead', 'xd'], tags='ENTJ'),
#  TaggedDocument(words=['mbtipc', 'perfect', 'dont', 'like', 'dealing', 'with', 'middle', 'men', 'either', 'you', 'can', 'talk', 'directly', 'to', 'me'], tags='ENTJ'),
#  TaggedDocument(words=['can', 'sell', 'you', 'the', 'dream'], tags='ENTJ'),
#  TaggedDocument(words=['lol', 'dead', 'ha'], tags='ENTJ'),
#  TaggedDocument(words=['the', 'point', 'is', 'that', 'when', 'you', 'are', 'making', 'point', 'of', 'thinking', 'critically', 'but', 'not', 'thinking', 'beyond', 'common', 'sense', 'you', 'arent', 'using', 'your', 'brain', 'little', 'bit', 'of', 'effort', 'now', 'to', 'have', 'an', 'understanding', 'of', 'the'], tags='ENTJ'),
#  TaggedDocument(words=['thats', 'just', 'common', 'sense', 'no', 'thats', 'just', 'value', 'judgement', 'backed', 'by', 'popular', 'opinion', 'from', 'social', 'thats', 'only', 'doing', 'what', 'works', 'instead', 'of', 'pushing', 'harder', 'and', 'doing', 'what', 'is'], tags='ENTJ'),
#  TaggedDocument(words=['when', 'it', 'comes', 'to', 'children', 'they', 'either', 'cry', 'or', 'climb', 'all', 'over', 'me', 'there', 'is', 'never', 'gray', 'area'], tags='ENTJ'),
#  TaggedDocument(words=['dont', 'drink', 'but', 'when', 'drank', 'beer', 'hardcore', 'ciders', 'and', 'sweet', 'brown', 'ales', 'liquor', 'vodka', 'chased', 'with', 'cran', 'or', 'water', 'my', 'preferred', 'drink', 'wine', 'anything', 'dark', 'dry', 'and', 'sweet', 'there', 'are', 'so'], tags='ENTJ'),
#  TaggedDocument(words=['well', 'that', 'escalated', 'quickly'], tags='ENTJ'),
#  TaggedDocument(words=['you', 'deal', 'with', 'them'], tags='ENTJ'),
#  TaggedDocument(words=['tldr'], tags='ENTJ'),
#  TaggedDocument(words=['those', 'people', 'who', 'think', 'they', 'know', 'everything', 'are', 'great', 'annoyance', 'to', 'those', 'of', 'us', 'who', 'do', 'ia'], tags='ENTJ'),
#  TaggedDocument(words=['darth', 'alpha', 'would', 'never', 'claim', 'it', 'to', 'be', 'healthy', 'either', 'just', 'in', 'my', 'best', 'interest'], tags='ENTJ'),
#  TaggedDocument(words=['on', 'loyalty', 'am', 'loyal', 'to', 'the', 'vision', 'am', 'loyal', 'to', 'those', 'who', 'share', 'the', 'vision', 'am', 'not', 'into', 'codependency', 'in', 'terms', 'of', 'the', 'vision', 'cannot', 'be', 'accomplished', 'without', 'others', 'involved', 'stay', 'on', 'course'], tags='ENTJ'),
#  TaggedDocument(words=['your', 'answer', 'was', 'worth', 'more', 'time', 'to', 'entertain', 'than', 'the', 'op'], tags='ENTJ'),
#  TaggedDocument(words=['hey', 'msbossypants', 'are', 'you', 'down', 'for', 'debate', 'on', 'ayn', 'rand', 'vs', 'marx', 'maybe', 'we', 'should', 'talk', 'about', 'our', 'poor', 'fi', 'oh', 'know', 'lets', 'try', 'to', 'correlate', 'testing', 'entj', 'with', 'being', 'sociopathic', 'laughing'], tags='ENTJ'),
#  TaggedDocument(words=['hitler', 'was', 'no', 'exception', 'this', 'concept', 'has', 'is', 'and', 'always', 'will', 'be', 'principle', 'tenet', 'and', 'rule', 'politics', 'ideology', 'religion', 'eating', 'shitting', 'usual', 'and', 'if', 'its', 'not', 'then', 'there', 'is', 'nothing', 'to'], tags='ENTJ'),
#  TaggedDocument(words=['hitler', 'thought', 'he', 'was', 'doing', 'great', 'things', 'stalin', 'thought', 'he', 'was', 'justified', 'these', 'guys', 'thought', 'they', 'were', 'uncorrupt', 'they', 'viewed', 'any', 'heretic', 'to', 'their', 'dogmas', 'as', 'morally', 'bankrupt', 'and', 'so', 'did', 'many', 'of'], tags='ENTJ'),
#  TaggedDocument(words=['meh', 'there', 'were', 'plenty', 'of', 'evil', 'people', 'who', 'did', 'good', 'things', 'and', 'plenty', 'of', 'good', 'people', 'who', 'got', 'blood', 'on', 'their', 'hands', 'achieving', 'and', 'attaining', 'higher', 'goals', 'bad', 'situations', 'that', 'had', 'good', 'long', 'term', 'effects'], tags='ENTJ'),
#  TaggedDocument(words=['you', 'would', 'have', 'to', 'ask', 'the', 'op', 'he', 'is', 'asking', 'ambiguous', 'questions', 'would', 'go', 'with', 'whatever', 'is', 'more', 'vs', 'what', 'is', 'perceived', 'as', 'good', 'every', 'time', 'in', 'the', 'good', 'vs', 'evil', 'dichotomy', 'it', 'in', 'my'], tags='ENTJ'),
#  TaggedDocument(words=['good', 'vs', 'bad', 'good', 'vs', 'evil', 'one', 'is', 'an', 'objective', 'positive', 'vs', 'negative', 'dichotomy', 'the', 'other', 'is', 'subjective', 'interpretation', 'of', 'characteristics', 'nameuser', 'so', 'to', 'be', 'evil', 'may', 'be', 'better', 'solution', 'and'], tags='ENTJ'),
#  TaggedDocument(words=['think', 'they', 'are', 'for', 'sure', 'idiots', 'but', 'also', 'think', 'these', 'people', 'went', 'out', 'of', 'their', 'way', 'to', 'fuck', 'their', 'lives', 'up', 'did', 'they', 'expose', 'themselves', 'on', 'the', 'internet', 'yes', 'does', 'this', 'warrant', 'or', 'validate', 'reason'], tags='ENTJ'),
#  TaggedDocument(words=['really', 'reeeeeeaaallly', 'hate', 'rigidly', 'pc', 'thumb', 'sucking', 'nanny', 'bitches', 'they', 'remind', 'me', 'of', 'five', 'year', 'olds', 'who', 'are', 'trying', 'too', 'hard', 'to', 'gain', 'their', 'parents', 'approval', 'by', 'taddling', 'these', 'are', 'the', 'same', 'people'], tags='ENTJ'),
#  TaggedDocument(words=['think', 'people', 'need', 'to', 'get', 'some', 'skin', 'even', 'if', 'these', 'people', 'are', 'wrong', 'or', 'racist', 'thats', 'just', 'waste', 'of', 'time', 'energy', 'and', 'resources', 'these', 'people', 'end', 'up', 'being', 'the', 'focus', 'for', 'being', 'petty', 'and', 'overboard'], tags='ENTJ'),
#  TaggedDocument(words=[], tags='ENTJ'),
#  TaggedDocument(words=[], tags='ENTJ'),
#  TaggedDocument(words=['im', 'not', 'trying', 'to', 'be', 'condescending', 'when', 'tell', 'you', 'all', 'those', 'things', 'you', 'have', 'mentioned', 'people', 'saying', 'and', 'have', 'written', 'off', 'as', 'all', 'have', 'been', 'met', 'with', 'are', 'legit', 'arguments', 'they', 'dont', 'need', 'to', 'be'], tags='ENTJ'),
#  TaggedDocument(words=['the', 'brevity', 'of', 'my', 'posts', 'is', 'because', 'you', 'dont', 'take', 'much', 'to', 'refute', 'just', 'because', 'you', 'arent', 'acknowledging', 'what', 'people', 'are', 'saying', 'doesnt', 'mean', 'they', 'are', 'saying', 'nothing'], tags='ENTJ'),
#  TaggedDocument(words=[], tags='INTJ'),
#  TaggedDocument(words=['science', 'is', 'not', 'perfect', 'no', 'scientist', 'claims', 'that', 'it', 'is', 'or', 'that', 'scientific', 'information', 'will', 'not', 'be', 'revised', 'as', 'we', 'discover', 'new', 'things', 'rational', 'thinking', 'has', 'been', 'very', 'useful', 'to', 'our', 'society'], tags='INTJ'),
#  TaggedDocument(words=['infp', 'edgar', 'allen', 'poe', 'was', 'an', 'infp', 'and', 'hes', 'in', 'your', 'siggy'], tags='INTJ'),
#  TaggedDocument(words=['people', 'see', 'the', 'obvious', 'fi', 'and', 'are', 'quick', 'to', 'put', 'her', 'as', 'infp', 'agree', 'that', 'she', 'has', 'no', 'ne', 'see', 'her', 'as', 'an', 'isfp', 'compare', 'her', 'to', 'haku', 'definite', 'infp', 'she', 'is', 'flat', 'through', 'most', 'of', 'naruto', 'but', 'dont'], tags='INTJ'),
#  TaggedDocument(words=['lets', 'get', 'this', 'party', 'started'], tags='INTJ'),
#  TaggedDocument(words=['did', 'not', 'say', 'it', 'disproved', 'god', 'merely', 'said', 'that', 'found', 'such', 'methods', 'disturbing', 'although', 'it', 'does', 'bring', 'up', 'certain', 'questions', 'god', 'is', 'in', 'control', 'of', 'the', 'universe', 'and', 'the', 'governments', 'of', 'the', 'world'], tags='INTJ'),
# ...
#  TaggedDocument(words=['oh', 'and', 'chazz', 'that', 'feeling', 'comes', 'and', 'goes', 'wouldnt', 'put', 'too', 'much', 'meaning', 'on', 'it', 'ever', 'since', 'can', 'remember', 'never', 'felt', 'like', 'belonged', 'anywhere', 'as', 'child', 'had', 'the', 'impression', 'that', 'my', 'presence', 'on'], tags='INFJ'),
#  TaggedDocument(words=['okay', 'totally', 'agree', 'with', 'your', 'post', 'but', 'couldnt', 'help', 'getting', 'visual', 'on', 'an', 'intimidating', 'typist', 'keep', 'seeing', 'roz', 'from', 'monsters', 'inc'], tags='INFJ'),
#  TaggedDocument(words=['it', 'takes', 'little', 'time', 'to', 'tell', 'the', 'difference', 'between', 'an', 'anxious', 'perception', 'and', 'clear', 'intuition', 'that', 'being', 'said', 'even', 'after', 'all', 'these', 'years', 'do', 'manage', 'to', 'screw', 'it', 'up', 'royally', 'at', 'times'], tags='INFJ'),
#  TaggedDocument(words=['great', 'movies', 'all', 'think', 'the', 'movie', 'that', 'still', 'moves', 'me', 'the', 'most', 'is', 'wings', 'of', 'desire', 'this', 'film', 'was', 'done', 'old', 'school', 'style', 'even', 'for', 'the', 'directed', 'by', 'wim', 'wenders', 'and', 'featuring', 'the', 'talent', 'of'], tags='INFJ'),
#  TaggedDocument(words=['im', 'not', 'sure', 'if', 'you', 'experience', 'this', 'or', 'maybe', 'because', 'im', 'middle', 'aged', 'that', 'see', 'things', 'this', 'way', 'have', 'been', 'musician', 'artist', 'salesman', 'soldier', 'nurse', 'cna', 'technician', 'christian', 'buddhist'], tags='INFJ'),
#  TaggedDocument(words=['first', 'found', 'out', 'about', 'mirror', 'neurons', 'from', 'reading', 'daniel', 'golemans', 'social', 'intelligence', 'though', 'the', 'credit', 'for', 'the', 'research', 'goes', 'to', 'an', 'italian', 'research', 'scientist', 'whose', 'name', 'escapes', 'me', 'for', 'the'], tags='INFJ'),
#  TaggedDocument(words=['aint', 'it', 'fun', 'to', 'be', 'us', 'ive', 'been', 'doing', 'some', 'reading', 'on', 'mirror', 'neurons', 'and', 'how', 'when', 'we', 'are', 'genuinely', 'engaged', 'with', 'another', 'human', 'being', 'our', 'brains', 'are', 'actually', 'in', 'sync', 'now', 'to', 'me', 'that', 'is'], tags='INFJ'),
#  TaggedDocument(words=['has', 'anyone', 'compiled', 'information', 'about', 'linking', 'mb', 'types', 'and', 'soma', 'types'], tags='INFJ'),
#  TaggedDocument(words=['wonder', 'if', 'our', 'expectations', 'of', 'ourselves', 'are', 'little', 'unrealistic', 'at', 'times', 'sometimes', 'feel', 'emotionally', 'raw', 'and', 'wounded', 'and', 'need', 'to', 'withdraw', 'oddly', 'enough', 'at', 'times', 'like', 'that', 'there', 'is', 'little'], tags='INFJ'),
#  TaggedDocument(words=['thats', 'normal', 'it', 'happens', 'also', 'to', 'me', 'if', 'am', 'in', 'high', 'mood', 'can', 'act', 'like', 'depressed', 'like', 'satisfied', 'and', 'relaxed', 'but', 'the', 'real', 'type', 'of', 'mine', 'is'], tags='INFP'),
#  TaggedDocument(words=['how', 'do', 'they', 'say', 'in', 'sheeps', 'clothing', 'that', 'is', 'the', 'key', 'nobody', 'will', 'obey', 'to', 'you', 'till', 'you', 'dont', 'give', 'them', 'the', 'chance', 'to', 'obey', 'you', 'without', 'consciously', 'knowing', 'they', 'are', 'obeying', 'you', 'be'], tags='INFP'),
#  TaggedDocument(words=['society', 'feels', 'compulsion', 'to', 'shield', 'itself', 'and', 'dissociate', 'itself', 'from', 'all', 'what', 'falls', 'on', 'point', 'distant', 'enough', 'from', 'the', 'norm', 'synonym', 'for', 'average', 'that', 'is', 'what', 'is', 'much', 'uglier', 'and', 'what', 'is'], tags='INFP'),
#  TaggedDocument(words=['the', 'thoroughly', 'intp', 'person', 'mission', 'in', 'life', 'is', 'deep', 'understanding', 'and', 'sheer', 'truth', 'the', 'thoroughly', 'infp', 'person', 'mission', 'in', 'life', 'is', 'deep', 'understanding', 'and', 'sheer', 'justice', 'in', 'the', 'sense', 'of', 'ruth', 'all'], tags='INFP'),
#  TaggedDocument(words=['when', 'you', 'visit', 'this', 'section', 'of', 'the', 'forum', 'and', 'feel', 'cosiness', 'instead', 'of', 'boredom', 'then', 'you', 'are', 'an', 'intp', 'or', 'maybe', 'an', 'infp', 'with', 'marked', 'thinking', 'facet', 'in', 'your', 'psyche', 'an', 'offbeat', 'outlandish', 'place'], tags='INFP'),
#  TaggedDocument(words=['from', 'book', 'read', 'yesterday', 'reminder', 'to', 'not', 'turn', 'into', 'js', 'the', 'real', 'meaning', 'of', 'is', 'wings', 'winged', 'folks', 'dont', 'give', 'in', 'to', 'flyphobia', 'albeit', 'sure', 'many', 'forces', 'all', 'around', 'us', 'try', 'to'], tags='INFP'),
#  TaggedDocument(words=['carrot', 'brocoli'], tags='INFP'),
#  TaggedDocument(words=['that', 'more', 'or', 'less', 'finds', 'myself', 'in', 'agreement', 'honey', 'cookie'], tags='INFP'),
#  TaggedDocument(words=['the', 'answers', 'nature', 'hinges', 'upon', 'two', 'points', 'how', 'does', 'he', 'rate', 'on', 'shyness', 'scale', 'the', 'more', 'shy', 'he', 'is', 'the', 'more', 'proactive', 'it', 'is', 'reasonable', 'that', 'your', 'attitude', 'be', 'what', 'is', 'your', 'main'], tags='INFP'),
#  TaggedDocument(words=['deleted'], tags='INFP'),
#  TaggedDocument(words=['ne', 'generates', 'suggestions', 'and', 'possibilities', 'to', 'make', 'the', 'workable', 'ones', 'into', 'ideas', 'must', 'come', 'into', 'play', 'ni', 'generates', 'solutions', 'it', 'prepares', 'the', 'ground', 'for', 'solutions', 'which', 'then', 'informs', 'they'], tags='INFP'),
#  TaggedDocument(words=['sweetheart'], tags='INFP'),
#  TaggedDocument(words=['something', 'want', 'to', 'share', 'sad', 'part', 'in', 'red', 'bolded', 'happy', 'part', 'in', 'green'], tags='INFP'),
#  TaggedDocument(words=['something', 'want', 'to', 'share', 'here', 'is', 'how', 'you', 'disturb', 'the', 'universe', 'to', 'make', 'meaning', 'it', 'isnxt', 'pretty', 'and', 'therexs', 'reason', 'most', 'who', 'are', 'able', 'to', 'do', 'it', 'on', 'grand', 'scale', 'are', 'above', 'forty', 'winning', 'before'], tags='INFP'),
#  TaggedDocument(words=['they', 'require', 'handiness', 'but', 'also', 'intelligence', 'video', 'games', 'are', 'split', 'as', 'follows', 'some', 'require', 'intelligence', 'others', 'intelligence', 'coupled', 'with', 'handiness', 'in', 'turn', 'those', 'requiring', 'intelligence', 'can'], tags='INFP'),
#  TaggedDocument(words=['equipoise'], tags='INFP'),
#  TaggedDocument(words=['but', 'if', 'your', 'goals', 'were', 'to', 'one', 'day', 'be', 'not', 'stranger', 'in', 'your', 'souls', 'territory', 'and', 'to', 'achieve', 'as', 'much', 'truth', 'as', 'possible', 'then', 'let', 'me', 'tell', 'you', 'that', 'your', 'condition', 'is', 'the', 'most', 'propitious', 'like'], tags='INFP'),
#  TaggedDocument(words=['socially', 'yes', 'and', 'family', 'belongs', 'in', 'society', 'but', 'the', 'best', 'would', 'be', 'to', 'be', 'as', 'honest', 'and', 'open', 'as', 'the', 'intelligence', 'maturity', 'and', 'degree', 'of', 'moral', 'development', 'of', 'the', 'other', 'person', 'allows'], tags='INFP'),
#  TaggedDocument(words=['am', 'sorry', 'that', 'you', 'think', 'that', 'it', 'is', 'obviously', 'an', 'fe', 'and', 'te', 'thing', 'introverted', 'judging', 'functions', 'are', 'innerdirected', 'feelings', 'and', 'thoughts', 'only', 'by', 'chance', 'and', 'to', 'some', 'extent', 'theyll', 'happen', 'to'], tags='INFP'),
#  TaggedDocument(words=['utilitarian', 'deceptive', 'and', 'selfdeceptive', 'falsely', 'altruistic', 'societally', 'programmed', 'feeling', 'and', 'utilitarian', 'earthbound', 'robotlike', 'societally', 'endorsed', 'thinking', 'fe', 'and', 'te', 'of', 'which', 'id', 'rather'], tags='INFP'),
#  TaggedDocument(words=['in', 'intpese', 'that', 'means', 'am', 'in', 'heartrending', 'love', 'with', 'you', 'my', 'baby', 'adoration', 'hearteyes'], tags='INFP'),
#  TaggedDocument(words=['always', 'test', 'and', 'and', 'am', 'an', 'intpish', 'infp', 'maybe', 'thats', 'why', 'my', 'first', 'motion', 'of', 'the', 'mind', 'was', 'why', 'is', 'none', 'of', 'them', 'providing', 'reasons', 'for', 'their', 'statements', 'in', 'the', 'intp', 'forum', 'theyd'], tags='INFP'),
#  TaggedDocument(words=['at', 'this', 'job', 'got', 'up', 'and', 'tore', 'his', 'robe', 'and', 'shaved', 'his', 'head', 'then', 'he', 'fell', 'to', 'the', 'ground', 'in', 'worship', 'and', 'saidxnaked', 'came', 'from', 'my', 'motherxs', 'womb', 'and', 'naked', 'will', 'depart', 'the', 'lord', 'gave', 'and', 'the', 'lord'], tags='INFP'),
#  TaggedDocument(words=['to', 'fetch'], tags='INFP'),
#  TaggedDocument(words=['can', 'the', 'wine', 'be', 'transferred', 'from', 'one', 'bottle', 'to', 'another', 'without', 'new', 'oxygen', 'being', 'added', 'incidentally', 'is', 'the', 'cesium', 'test', 'cheaper', 'than', 'the', 'oxygen', 'test', 'these', 'are', 'the', 'two', 'questions', 'coming', 'to', 'my'], tags='INFP'),
#  TaggedDocument(words=['hatch'], tags='INFP'),
#  TaggedDocument(words=['its', 'sly', 'way', 'to', 'assess', 'the', 'test', 'takers', 'consistency', 'and', 'when', 'it', 'is', 'not', 'that', 'the', 'different', 'words', 'import', 'subtle', 'change', 'in', 'meaning'], tags='INFP'),
#  TaggedDocument(words=['you', 'probably', 'go', 'there', 'with', 'the', 'wrong', 'expectation', 'that', 'its', 'place', 'for', 'debate', 'smileycool'], tags='INFP'),
#  TaggedDocument(words=['infps', 'and', 'coding', 'are', 'destined', 'to', 'entertain', 'paradoxical', 'relation', 'they', 'are', 'among', 'the', 'most', 'intelligent', 'people', 'coding', 'is', 'an', 'ideal', 'outlet', 'for', 'intelligence', 'therefore', 'part', 'of', 'their', 'self', 'will'], tags='INFP'),
#  TaggedDocument(words=['infps', 'and', 'gymnastics', 'that', 'would', 'be', 'an', 'interesting', 'research', 'topic', 'cheers', 'eagerness', 'just', 'came', 'across', 'this', 'and', 'couldnt', 'help', 'but', 'think', 'of', 'certain', 'enneagrammbti'], tags='INFP'),
#  TaggedDocument(words=['anybody', 'who', 'to', 'my', 'signature', 'is', 'welcome', 'is', 'this', 'snarky', 'way', 'to', 'say', 'noones', 'welcome', 'dont', 'know', 'myself', 'welcome'], tags='INFP'),
#  TaggedDocument(words=['well', 'what', 'if', 'the', 'forgery', 'is', 'bottle', 'that', 'was', 'filled', 'in', 'say', 'oxygen', 'content', 'would', 'be', 'low', 'but', 'there', 'would', 'be', 'cesium'], tags='INFP'),
#  TaggedDocument(words=['simple', 'search', 'for', 'mbti', 'types', 'intelligence', 'will', 'yield', 'enough', 'results', 'giftednongifted', 'ratios', 'by', 'type', 'this', 'is', 'good', 'tothepoint', 'resume', 'obviously', 'infps', 'would', 'top', 'other', 'charts'], tags='INFP'),
#  TaggedDocument(words=['an', 'infp', 'may', 'turn', 'when', 'surrounded', 'by', 'people', 'gapingly', 'less', 'intelligent', 'rational', 'selfaware', 'in', 'other', 'words', 'mentally', 'developed', 'it', 'is', 'much', 'burdensome', 'because', 'wed', 'like', 'to', 'involve', 'ourselves'], tags='INFP'),
#  TaggedDocument(words=['writing', 'desk'], tags='INFP'),
#  TaggedDocument(words=['there', 'lot', 'among', 'the', 'true', 'nonmainstream', 'mostly', 'artists', 'poets', 'and', 'so', 'on', 'even', 'psychologists', 'its', 'easier', 'to', 'meet', 'them', 'by', 'reading', 'watching', 'good', 'motion', 'picture', 'than', 'directly', 'in', 'daily'], tags='INFP'),
#  TaggedDocument(words=['what', 'would', 'you', 'demand', 'of', 'life', 'to', 'make', 'you', 'more', 'sensitive', 'without', 'having', 'to', 'pay', 'for', 'it', 'somehow', 'no', 'good', 'lunch', 'is', 'for', 'free', 'as', 'for', 'school', 'work', 'you', 'will', 'always', 'be', 'slower', 'than', 'people', 'of', 'the', 'same'], tags='INFP'),
#  TaggedDocument(words=[], tags='INFP'),
#  TaggedDocument(words=['in', 'the', 'wake', 'of', 'your', 'post', 'read', 'about', 'the', 'types', 'deadly', 'sins', 'and', 'virtues', 'well', 'what', 'to', 'say', 'the', 'enneagram', 'theory', 'is', 'pettyminded', 'in', 'many', 'places', 'its', 'commercial', 'product', 'of', 'the'], tags='INFP'),
#  TaggedDocument(words=['never', 'thought', 'intps', 'could', 'be', 'showoffs', 'occasionally', 'eek', 'maybe', 'because', 'in', 'real', 'life', 'they', 'are', 'shy', 'at', 'all', 'times'], tags='INFP'),
#  TaggedDocument(words=['types', 'arent', 'fixed', 'places', 'for', 'human', 'the', 'mind', 'shifts', 'to', 'neat', 'one', 'sometimes', 'or', 'you', 'keep', 'being', 'the', 'same', 'one', 'but', 'your', 'of', 'and', 'or', 'any', 'other', 'pair', 'vary'], tags='INFP'),
#  TaggedDocument(words=['you', 'dont', 'say', 'thwink'], tags='INFP'),
#  TaggedDocument(words=['harshly', 'shut', 'down', 'others', 'opinions', 'or', 'call', 'them', 'out', 'on', 'their', 'bullshit', 'they', 'have', 'the', 'cheekiness', 'to', 'do', 'it', 'in', 'realworld', 'setting', 'we', 'do', 'exactly', 'the', 'same', 'just', 'in', 'our', 'mind', 'or', 'online', 'although'], tags='INFP'),
#  TaggedDocument(words=['ah', 'the', 'entj', 'who', 'knows', 'she', 'is', 'evil', 'and', 'domineering', 'is', 'the', 'only', 'entj', 'like', 'and', 'the', 'least', 'evil', 'and', 'domineering', 'of', 'them', 'smilenew', 'puffer'], tags='INFP'),
#  TaggedDocument(words=['so', 'today', 'you', 'didnt', 'spam', 'your', 'fakebook', 'wall', 'with', 'waterfall', 'of', 'happy', 'inlove', 'loveuallguys'], tags='INFP'),
#  TaggedDocument(words=['as', 'others', 'said', 'ere', 'you', 'are', 'an', 'obvious', 'isfp', 'you', 'and', 'we', 'infps', 'are', 'much', 'alike', 'screw', 'social', 'norms', 'and', 'in', 'general', 'the', 'ability', 'to', 'have', 'an', 'identity', 'of', 'our', 'own', 'emotional', 'and', 'at', 'once', 'much'], tags='INFP'),
#  TaggedDocument(words=['isfps', 'are', 'among', 'the', 'extremely', 'few', 'types', 'id', 'like', 'to', 'be', 'romantically', 'involved', 'with', 'along', 'with', 'infps', 'such', 'as', 'myself', 'and', 'intps', 'angel'], tags='INFP'),
#  TaggedDocument(words=['as', 'though', 'emmersed', 'winky'], tags='INFP'),
#  TaggedDocument(words=['nobody', 'has', 'voted', 'for', 'ni', 'looks', 'like', 'lot', 'of', 'infps', 'like', 'strategy', 'games', 'and', 'planning', 'tasks'], tags='INFP'),
#  TaggedDocument(words=['this', 'doesnt', 'look', 'like', 'strange', 'enfp', 'behavior', 'at', 'all', 'am', 'an', 'infp', 'but', 'when', 'in', 'high', 'spirits', 'ill', 'act', 'extroverted', 'and', 'like', 'this', 'he', 'may', 'be', 'busy', 'pursuing', 'other', 'women', 'to', 'make', 'out', 'with', 'in', 'the', 'coming'], tags='INFP'),
#  TaggedDocument(words=['steve', 'jobs', 'was', 'recognized', 'for', 'his', 'striving', 'for', 'efficiency', 'and', 'practicality', 'his', 'genius', 'is', 'in', 'his', 'systemization', 'of', 'inventions', 'less', 'so', 'than', 'in', 'invention', 'this', 'is', 'where', 'claims', 'of', 'se', 'and', 'te', 'come', 'from'], tags='INTP'),
#  TaggedDocument(words=['pencil', 'not', 'inf', 'fe', 'type', 'emotion', 'type', 'what', 'drove', 'emotion'], tags='INTP'),
#  TaggedDocument(words=['obvious', 'troll'], tags='INTP'),
#  TaggedDocument(words=['but', 'either', 'way', 'hed', 'get', 'there', 'by', 'use', 'of', 'his', 'ni', 'or', 'te', 'you', 'can', 'get', 'any', 'behavior', 'with', 'any', 'cognition', 'all', 'cognition', 'describes', 'is', 'the', 'thought', 'process', 'which', 'may', 'be', 'prone', 'to', 'develop', 'certain', 'behaviors'], tags='INTP'),
#  TaggedDocument(words=['every', 'edgy', 'ntp', 'and', 'their', 'mother', 'acts', 'on', 'their', 'off', 'days', 'the', 'very', 'idea', 'of', 'borrowing', 'types', 'and', 'progressively', 'chameleoning', 'screams', 'ne', 'and', 'fe', 'specifically', 'in', 'that', 'order'], tags='INTP'),
#  TaggedDocument(words=['its', 'cause', 'you', 'spend', 'all', 'your', 'time', 'irl', 'ignoring', 'your', 'need', 'for', 'expression', 'so', 'now', 'youre', 'excitedly', 'exaggerating', 'and', 'projecting', 'your', 'weirdness', 'because', 'you', 'get', 'aroused', 'off', 'the', 'image', 'of', 'you', 'it', 'puts', 'in'], tags='INTP'),
#  TaggedDocument(words=['just', 'gonna', 'ignore', 'all', 'your', 'rules', 'si', 'normal', 'se', 'fighting', 'ni', 'psychic', 'ne', 'electric', 'ti', 'steel', 'te', 'dark', 'fi', 'grass', 'fe', 'fairy'], tags='INTP'),
#  TaggedDocument(words=['ixfj', 'must', 'research', 'si', 'vs', 'ni', 'suck', 'at', 'those', 'two'], tags='INTP'),
#  ...]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Create train/test datasets

# %%
total_num_obs = len(df)
train_corpus = df[0:floor(3*total_num_obs/4)]
test_corpus = df[floor(3*total_num_obs/4):]

train_posts, train_ie, train_sn, train_tf, train_pj = zip(*[(doc.words, doc.tags[0], doc.tags[1], doc.tags[2],doc.tags[3]) for doc in train_corpus])
test_posts, test_ie, test_sn, test_tf, test_pj = zip(*[(doc.words, doc.tags[0], doc.tags[1], doc.tags[2], doc.tags[3]) for doc in test_corpus])

# %% [markdown]
# ### Vectorize posts by using doc2vec

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=100, min_count=2, epochs=55)
model.build_vocab(train_corpus) 
# %time model.train(train_corpus, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# /Users/shoki/.anyenv/envs/pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# CPU times: user 1h 7min 53s, sys: 6min 45s, total: 1h 14min 38s
# Wall time: 1h 9min 47s

# %%
#play
model.infer_vector(['I', 'feel', 'sad'])
# Out:
# array([ 2.17016950e-01,  6.33819401e-02,  3.35046798e-01,  1.19797245e-01,
#        -2.42761627e-01,  1.84276812e-02,  1.95870310e-01,  2.44808244e-03,
#         6.57461062e-02, -4.67282027e-01,  8.18292499e-02, -1.99449763e-01,
#         9.10089761e-02,  6.07760213e-02,  1.99488014e-01, -1.58947967e-02,
#        -3.28436553e-01,  3.40462960e-02,  3.17493349e-01,  1.43035695e-01,
#         9.01819244e-02,  2.95271307e-01,  5.84785268e-02, -1.83005586e-01,
#         9.03692283e-03,  1.16019398e-01,  4.35855649e-02, -4.19977456e-01,
#        -1.11678116e-01, -1.73624381e-01, -1.42633140e-01,  1.32786870e-01,
#         7.99428374e-02, -7.64770061e-02,  2.22472191e-01, -2.34965786e-01,
#         2.29628563e-01, -6.03820905e-02,  3.58959317e-01, -3.11051607e-01,
#        -8.29173028e-02, -2.75319740e-02,  2.50556737e-01, -3.49292129e-01,
#         4.75158393e-01,  8.46895650e-02,  1.14725180e-01,  1.93300918e-01,
#         8.80713388e-02, -3.11572284e-01,  3.12334771e-04,  5.81724662e-03,
#         1.05216295e-01,  9.00478065e-02,  5.60687035e-02,  1.13411456e-01,
#         7.22875353e-03,  8.98259319e-03, -1.44401371e-01, -3.35210234e-01,
#         1.15275741e-01, -8.91692787e-02,  5.74271902e-02, -2.34325826e-01,
#        -2.02306136e-01, -2.74132341e-01,  9.19829011e-02,  3.96635354e-01,
#        -2.37789854e-01, -3.76254946e-01,  1.00091891e-02, -1.32884264e-01,
#        -4.02833372e-02,  2.58202970e-01, -9.37351733e-02, -2.79482026e-02,
#        -1.14120625e-01, -3.21294554e-02,  2.25205556e-01,  1.60162523e-01,
#        -9.26480591e-02,  1.41571015e-01,  1.41282097e-01, -1.10498153e-01,
#         2.43267894e-01, -1.13849699e-01,  1.90962270e-01, -3.20047230e-01,
#        -1.88202914e-02, -3.68195809e-02,  2.73450077e-01,  2.31624469e-02,
#         1.19021744e-01, -1.76264629e-01, -2.41299123e-02, -2.80264616e-02,
#        -2.77888447e-01,  4.55265969e-01,  1.90531269e-01, -2.05199882e-01],
#       dtype=float32)

# %% [markdown]
# ### Create input data for modeling

# %%
# X_train
X = []
for i in range(len(train_posts)):
    X.append(model.infer_vector(train_posts[i]))
X_train = np.asarray(X)

with open("../output/X_train.pickle", "wb") as f:
    pickle.dump(X_train, f)

# %%
# y_train
y_train = []
y_train_ie = np.asarray([1 if i  ==  'I' else 0 for i in train_ie])
y_train_sn = np.asarray([1 if i  ==  'S' else 0 for i in train_sn])
y_train_tf = np.asarray([1 if i  ==  'T' else 0 for i in train_tf])
y_train_pj = np.asarray([1 if i  ==  'P' else 0 for i in train_pj])

y_train = [y_train_ie, y_train_sn, y_train_tf, y_train_pj]

with open("../output/y_train.pickle", "wb") as f:
    pickle.dump(y_train, f)

# %%
# X_test
X = []
for i in range(len(test_posts)):
    X.append(model.infer_vector(test_posts[i]))
X_test = np.asarray(X)

with open("../output/X_test.pickle", "wb") as f:
    pickle.dump(X_test, f)

# %%
y_test = []
y_test_ie = np.asarray([1 if i  ==  'I' else 0 for i in test_ie])
y_test_sn = np.asarray([1 if i  ==  'S' else 0 for i in test_sn])
y_test_tf = np.asarray([1 if i  ==  'T' else 0 for i in test_tf])
y_test_pj = np.asarray([1 if i  ==  'P' else 0 for i in test_pj])

y_test = [y_test_ie, y_test_sn, y_test_tf, y_test_pj]

with open("../output/y_test.pickle", "wb") as f:
    pickle.dump(y_test, f)

# %%
X_train
# Out:
# array([[ 4.8813503e-04,  2.1518937e-03,  1.0276338e-03, ...,
#         -4.7989246e-03,  3.2894004e-03, -4.9530454e-03],
#        [ 4.8813503e-04,  2.1518937e-03,  1.0276338e-03, ...,
#         -4.7989246e-03,  3.2894004e-03, -4.9530454e-03],
#        [ 9.4345367e-01, -2.0982254e-01,  1.5262055e-01, ...,
#          7.5583100e-01,  4.1577938e-01, -2.7711844e-01],
#        ...,
#        [ 1.2341156e+00,  6.3739276e-01,  5.5347365e-01, ...,
#          7.2877151e-01,  8.4644639e-01, -1.0720488e+00],
#        [ 7.4467766e-01,  2.0597140e-01,  4.9148655e-01, ...,
#          1.1011819e+00,  6.7666107e-01, -6.4249265e-01],
#        [ 7.7941608e-01,  9.1801904e-02,  7.5938648e-01, ...,
#          1.3652763e+00,  4.0801057e-01, -1.2346441e+00]], dtype=float32)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Make models by using RandomForestClassifier / LogisticRegression

# %%
rfc_ie = RandomForestClassifier()
rfc_ie.fit(X_train, y_train[0])

rfc_sn = RandomForestClassifier()
rfc_sn.fit(X_train, y_train[1])

rfc_tf = RandomForestClassifier()
rfc_tf.fit(X_train, y_train[2])

rfc_pj = RandomForestClassifier()
rfc_pj.fit(X_train, y_train[3])
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
logreg_ie = linear_model.LogisticRegression()
logreg_ie.fit(X_train, y_train[0])

logreg_sn = linear_model.LogisticRegression()
logreg_sn.fit(X_train, y_train[1])

logreg_tf = linear_model.LogisticRegression()
logreg_tf.fit(X_train, y_train[2])

logreg_pj = linear_model.LogisticRegression()
logreg_pj.fit(X_train, y_train[3])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ### Verify models by samples

# %%
X_sample = "I feel sad"
X_sample = gensim.utils.simple_preprocess(X_sample)
X_sample = model.infer_vector(X_sample)
X_sample = np.array(X_sample).reshape(1, 100).tolist()

# %%
y_sample = logreg_tf.predict_proba(X_sample)
y_sample
# Out:
# array([[0.4935395, 0.5064605]])

# %% [markdown]
# ### Test models

# %%
y_predict = []
for y in [rfc_ie, rfc_sn, rfc_tf, rfc_pj]:
    y_predict.append(y.predict(X_test))

# %%
print(sum(y_predict[0] == y_test[0]) / len(y_test[0]))
print(sum(y_predict[1] == y_test[1]) / len(y_test[0]))
print(sum(y_predict[2] == y_test[2]) / len(y_test[0]))
print(sum(y_predict[3] == y_test[3]) / len(y_test[0]))
# Out:
# 0.7675665960345088
# 0.8614726804903889
# 0.5654324958377478
# 0.5877194642046315

# %%
y_predict = []
for y in [logreg_ie, logreg_sn, logreg_tf, logreg_pj]:
    y_predict.append(y.predict(X_test))

# %%
print(sum(y_predict[0] == y_test[0]) / len(y_test[0]))
print(sum(y_predict[1] == y_test[1]) / len(y_test[0]))
print(sum(y_predict[2] == y_test[2]) / len(y_test[0]))
print(sum(y_predict[3] == y_test[3]) / len(y_test[0]))
# Out:
# 0.7606894203117905
# 0.8568752837899197
# 0.5918911760254276
# 0.5965358710458605

# %% [markdown]
# ### Dump models

# %%
with open("../output/model.pickle", "wb") as f:
    pickle.dump(model, f)

# %%
with open("../output/logreg_ie.pickle", "wb") as f:
     pickle.dump(logreg_ie, f)
    
with open("../output/logreg_sn.pickle", "wb") as f:
     pickle.dump(logreg_sn, f)

with open("../output/logreg_tf.pickle", "wb") as f:
     pickle.dump(logreg_tf, f)
        
with open("../output/logreg_pj.pickle", "wb") as f:
     pickle.dump(logreg_pj, f)

# %% [markdown]
# ## with open("../output/rfc_ie.pickle", "wb") as f:
#      pickle.dump(rfc_ie, f)
#
# with open("../output/rfc_sn.pickle", "wb") as f:
#      pickle.dump(rfc_sn, f)
#
# with open("../output/rfc_tf.pickle", "wb") as f:
#      pickle.dump(rfc_tf, f)
#
# with open("../output/rfc_pj.pickle", "wb") as f:
#      pickle.dump(rfc_pj, f)
